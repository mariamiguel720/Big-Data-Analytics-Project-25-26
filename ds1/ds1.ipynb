# %%
import sqlite3
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
monster_job_sample = pd.read_csv("../data/monster_job_sample.csv",index_col=0)

# %%
monster=monster_job_sample.copy()

# %%
pd.set_option('display.max_columns', None)

# %%
monster.head()
# Out:
#                          country_code date_added has_expired  \
# country
# United States of America           US        NaN          No
# United States of America           US        NaN          No
# United States of America           US        NaN          No
# United States of America           US        NaN          No
# United States of America           US        NaN          No
#
#                                  job_board  \
# country
# United States of America  jobs.monster.com
# United States of America  jobs.monster.com
# United States of America  jobs.monster.com
# United States of America  jobs.monster.com
# United States of America  jobs.monster.com
#
#                                                             job_description  \
# country
# United States of America  TeamSoft is seeing an IT Support Specialist to...
# United States of America  The Wisconsin State Journal is seeking a flexi...
# ...
